# %% [markdown]
# # Data Visualization Ethics Challenge
#
# In this activity, you’ll work with a simple dataset and examine two deliberately bad charts.
# Each one ignores multiple best practices for ethical and effective visualization.
#
# Your job is to:
#
# 1. Review each chart and note at least three issues you see.
# 2. Create a new chart (or charts) that present the data clearly, accurately, and honestly.
# 3. Include clear labels, a cited data source, and a descriptive but neutral title.
#
# **Remember:** Strong visualizations tell the truth, provide context, and avoid design choices that distort or mislead.

# %% [markdown]
# ## Step 1: Load the dataset
#
# We’re using a provided CSV file with fictional sales data for a coffee chain.
# No need to modify anything in this cell — just run it so the dataset loads into your notebook.
# Once loaded, take a quick look at the first few rows to get familiar with the columns and values.

# %%
import pandas as pd
import matplotlib.pyplot as plt

coffee_df = pd.read_csv("fake_coffee_chain_sales.csv")
coffee_df.head()
# Out:
#    Year    Month Region  Category  Sales   Profit
# 0  2020  January   East  Espresso  14724  5290.46
# 1  2020  January   East    Lattes  11948  4138.77
# 2  2020  January   East       Tea  18660  5959.44
# 3  2020  January   East  Pastries  11265  2604.46
# 4  2020  January   East     Beans   8954  2613.22

# %%
coffee_df.shape
# Out:
# (1200, 6)

# %%
coffee_df.groupby("Year")["Sales"].sum().reset_index()
# Out:
#    Year    Sales
# 0  2020  3120583
# 1  2021  2953939
# 2  2022  3006869
# 3  2023  3031845
# 4  2024  3200372

# %% [markdown]
# ## Step 2: Review the BAD Charts
#
# Below are two deliberately poor visualizations.
# Your task: Carefully review each and take notes on what you think is wrong, misleading, or just poorly designed.
# Think about chart type, colors, scales, labeling, and whether the chart tells the truth.

# %%
plt.figure(figsize=(8,5))
subset = coffee_df.groupby("Year")["Sales"].sum().reset_index()

# Wrong variable for title, truncated y-axis, misleading color & framing
plt.plot(subset["Year"], subset["Sales"], color="red", linewidth=4, marker="o")
plt.ylim(subset["Sales"].min() * 0.98, subset["Sales"].min() * 1.02)  # extreme truncation
plt.title("Shocking Collapse in Profits!", fontsize=16, fontweight="bold", color="darkred")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ### Write your notes about bad chart #1 here:
# (double click to open this markdown cell and type into it)
#
# - figsize (8,5) is small for the chart.
# - Lineweidth 4 is thick and red color is too bright for color blind people.
# - plt.ylim(subset["Sales"].min() * 0.98, subset["Sales"].min() * 1.02)
#        this truncates y axis and even a small fluctuation make it look very big and mislead data.
# - Title is too much exaggerating, not perfect for data.
# - No label for X and Y axis.

# %%
plt.figure(figsize=(10,6))
avg_sales = coffee_df.groupby("Region")["Sales"].mean().reset_index()

colors = ["red","orange","yellow","green","blue","purple"]

plt.bar(avg_sales["Region"], avg_sales["Sales"], 
        color=colors, edgecolor="black", linewidth=3, hatch="/", alpha=0.8)
plt.title("!!! INCREDIBLE SALES DATA !!!", fontsize=20, fontweight="bold", color="purple", backgroundcolor="yellow")
plt.grid(True, which='both', color='black', linestyle='-', linewidth=1.5)
plt.xlabel("Region of the WORLD!!!!", fontsize=16, fontweight="bold", color="darkgreen")
plt.ylabel("MONEY $$$$$", fontsize=16, fontweight="bold", color="darkblue")
plt.xticks(rotation=45, fontsize=14, fontweight="bold", color="orange")
plt.yticks(fontsize=14, fontweight="bold", color="orange")
plt.show()

# %% [markdown]
# ### Write your notes about bad chart #2 here:
# (double click to open this markdown cell and type into it)
#
# - Too many strong colors, confusing for eyes.
# - thick black boarder and hatch /.
# - Background color on title may draws attentation away from data.
# - overcrowded and very dark grid.

# %% [markdown]
# ## Step 3: Your Turn – Make It Right
#
# Now it’s your turn to fix things.
#
# - Start by thinking about a question you want to answer with this dataset.
# - Choose a visualization type that matches your question and the data structure.
# - Apply the best practices from our lessons: clear labeling, appropriate scale, purposeful color, simplicity, and accessibility.
# - Be honest - don’t manipulate the chart to make a point that the data doesn’t support.
#
# When you’re done, add your chart(s) below. You may create more than one if it helps tell the story better.

# %%
# Your GOOD visualization(s) here

# %%
# Average coffee Sales by Year
plt.figure(figsize=(10,6)) # larger feigure makes chart easier to read and understand.
subset = coffee_df.groupby("Year")["Sales"].sum().reset_index()


# Wrong variable for title, truncated y-axis, misleading color & framing
plt.plot(subset["Year"], subset["Sales"], color="tomato", linewidth=2, marker="o")
#plt.ylim(subset["Sales"].min() * 0.90, subset["Sales"].min() * 1.10)  # extreme truncation


plt.ylim(0,subset["Sales"].max()*1.10) #y axis start from 0 and goes 10% avove the maximum value


plt.title("Coffee Sales Recovered After 2021 Dip & Peaked in 2024" , fontsize=16, fontweight="bold", color="Black", pad=60) #changed title and gave padding to make chart neat.
plt.xlabel("Year",fontsize=14,fontweight="bold", color="Black") #labeled x-axis
plt.ylabel("Sales (Millions)",fontsize=14,fontweight="bold", color="Black")#labeled y-axis
ax = plt.gca()
ax.spines['top'].set_visible(False) # removed unnesserry bordeer to make chart clean
ax.spines['right'].set_visible(False)
plt.xticks(subset["Year"],fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# ### changes I made to the chart:
# - The original figsize (8,5) was small, so i increased to (10,6) to improve readability.
# - A thick line (linewidth=4) replaced with 2, and color also changed to soft red.
# - y axis now start from 0 and goes 10% avove the maximum value, which fits all data points in the chart.
# - The original missleading title replaced with insight-based title.
# - x and y labels are added.
# - unnecessary top and right boarders are removed.
# - Padding was added to title tor improve layout.

# %%
#Average Coffee sales by Region
plt.figure(figsize=(10,6))
avg_sales = coffee_df.groupby("Region")["Sales"].mean().reset_index()
print(avg_sales)
colors = ["red","orange","yellow","green","blue","purple"]

plt.bar(avg_sales["Region"], avg_sales["Sales"], 
        color="green", edgecolor="black", linewidth=2, alpha=0.5) #soft green easy for eyes.
plt.title("Average  Coffee Sales by Region", fontsize=16, fontweight="bold", color="black",pad=30)#, backgroundcolor="yellow") #changed title, padding for spacing over the chart.
plt.grid(True, axis='y', color='black', linestyle='--', linewidth=1.5, alpha=0.3) # light dashed grid only on y axis for easy for eye and less cluttering

plt.xlabel("Region", fontsize=14, fontweight="bold", color="black")
plt.ylabel("Sales (Thousands)", fontsize=14, fontweight="bold", color="black")
plt.bar_label(bars, labels=[int(x) for x in avg_sales['Sales']], padding=10) # creating bar labels to show sales label 

plt.xticks(rotation=30, fontsize=14, color="black")
plt.yticks(fontsize=14,  color="black")

#remove unnecessary grids for neat look
ax=plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()
# Out:
#   Region         Sales
# 0   East  12923.376667
# 1  North  12692.986667
# 2  South  12451.780000
# 3   West  12977.216667

# %% [markdown]
# ### Change i made to the chart:
# - Removed the original bright colors and heavy styling to reduce distraction.
# - used single soft color to make the chart easier to read.
# - changed the title to clear one.
# - added proper x and y labels.
# - removed unnecessary boarders.
# - added bar value to make exact values easy to read.
# - Kept light dashed gridline only on y-axis for clarity.
